# %% [markdown]
# ## Get page html content

# %%
import pandas as pd
import time
import glob
from selenium import webdriver
from selenium.webdriver.common.by import By
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Request

# %%
search_url = 'https://www.bger.ch/ext/eurospider/live/fr/php/aza/http/index.php?lang=fr&type=highlight_simple_query&page=1&from_date=&to_date=&sort=relevance&insertion_date=&top_subcollection_aza=all&query_words=&rank=3&azaclir=aza&highlight_docid=aza%3A%2F%2F20-06-2018-6B_447-2018&number_of_ranks=118028'

# %%
request_headers = {
    "method": "GET",
    "user-agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36"
}

# %%
html = requests.get(search_url, headers=request_headers)

# %%
html.encoding = 'iso-8859-1'

# %%
soup = BeautifulSoup(html.content, "html5lib")
soup
r = requests.get(url)
r.encoding
# Out:
# 'iso-8859-1'

# %%
#encoding = html.encoding if 'charset' in html.headers.get('content-type', '').lower() else None
#soup = BeautifulSoup(html.content, "html5lib", from_encoding=encoding)
#soup

# %%
page_text = ''
for strong_tag in soup.find_all('div', {'class': 'para'}):
    page_text += strong_tag.get_text()

# %%
page_text
# Out:
# "�Bundesgericht�Tribunal f�d�ral�Tribunale federale�Tribunal federal�����������������\n  \n  \n���\n    \n  6B_447/2018\n  \n���\n    \n  Arr�t du 20 juin 2018\n  \n��\n    \n  Cour de droit p�nal\n  \n��Composition�MM. et Mme les Juges f�d�raux Denys, Pr�sident, Jacquemoud-Rossari et Oberholzer.�Greffier : M. Dyens.��Participants � la proc�dure�X.________,�repr�sent� par Me Philippe Baudraz, avocat,�recourant,��\n    \n  contre\n  \n��Minist�re public central du canton de Vaud,�intim�.��Objet�Violation grave des r�gles de la circulation routi�re; arbitraire; quotit� de la peine, �tat de n�cessit�,��recours contre le jugement de la Cour d'appel p�nale du Tribunal cantonal du canton de Vaud du 24 janvier 2018 (AM16.019220/GALN/TDE).���\n    \n  Faits :\n  \n��\n    \n  A.�\n�Par jugement du 10 octobre 2017, le Tribunal de police de l'arrondissement de Lausanne a reconnu X.________ coupable de violation grave et simple des r�gles de la circulation routi�re, l'a condamn� � une peine p�c
# ...

# %% [markdown]
# ## PhantomJS method

# %%
date = time.strftime("%Y%m%d%H%M%S")

# %%
driver = webdriver.PhantomJS()
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '

# %%
search_url = urls.loc[0]['url']

# %%
driver.set_window_size(1124, 5000)
driver.get(search_url)

# %%
text = (driver.page_source)
page_text = ''
for strong_tag in soup.find_all('div', {'class': 'para'}):
    page_text += strong_tag.get_text()

# %%
page_text
# Out:
# '\xa0Bundesgericht\xa0Tribunal fédéral\xa0Tribunale federale\xa0Tribunal federal\xa0\xa0\xa0\n    \n  \n    \n      \n        \n      \n      \n        \xa0\n      \n      \n        \xa0\n      \n    \n    \n      \n        {T\xa00/2}\xa0\n        \xa0\n        \n        \n          5A_686/2013 \n      \n        \xa0\n      \n      \n        \xa0 \xa0\n      \n      \n        \xa0 \xa0\n      \n    \n  \n  \n\xa0\xa0\xa0{T\xa00/2}\xa0\xa0\n        \n          5A_686/2013 \n      \n        \xa0\xa0 \xa0\xa0 \xa0\xa0\xa0\n    \n  Arrêt du 31 janvier 2014\n  \n\xa0\xa0\n    \n  IIe Cour de droit civil\n  \n\xa0\xa0Composition\xa0MM. et Mme les Juges fédéraux von Werdt, Président, Hohl, Marazzi, Herrmann et Schöbi.\xa0Greffière: Mme Hildbrand.\xa0\xa0Participants à la procédure\xa0A.X.________,\xa0représenté par Me Olivier Righetti, avocat,\xa0recourant,\xa0\xa0\n    \n  contre\n  \n\xa0\xa0\n    \n  Banque Z.________,\n\xa0représentée par Me Jean-Samuel Leuba, avocat,\xa0intimée.\xa0\xa
# ...

# %%
with open("folder/" +date+".htm", "wb+") as file: 
    file.write(text)
    file.close()

driver.close()
